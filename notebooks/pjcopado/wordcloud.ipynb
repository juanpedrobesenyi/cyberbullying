# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import wordcloud
from wordcloud import WordCloud

# %%
df = pd.read_csv('../../cyberbullying/data/all_df.csv')
#df = pd.read_csv('../../cyberbullying/data/twitter_parsed_dataset.csv')

df.head()
# Out:
#                                                 text  target
# 0  this one can make an analogy in mathematical t...     0.0
# 1  clarification for you and zundark s right i sh...     0.0
# 2                           elected or electoral jhk     0.0
# 3  this is such a fun entry devotchka i once had ...     0.0
# 4  please relate the ozone hole to increases in c...     0.0

# %%
df.shape
# Out:
# (227423, 2)

# %%
df['text'][0]
# Out:
# 'this one can make an analogy in mathematical terms by envisioning the distribution of opinions in a population as a gaussian curve we would then say that the consensus would be a statement that represents the range of opinions within perhaps three standard deviations of the mean opinion sounds arbitrary and ad hoc does it really belong in n encyclopedia article i don t see that it adds anything useful the paragraph that follows seems much more useful are there any political theorists out there who can clarify the issues it seems to me that this is an issue that locke rousseau de toqueville and others must have debated sr'

# %%
text = ''.join(df['text'])

# %%
df['text']
# Out:
# 0         this one can make an analogy in mathematical t...
# 1         clarification for you and zundark s right i sh...
# 2                                  elected or electoral jhk
# 3         this is such a fun entry devotchka i once had ...
# 4         please relate the ozone hole to increases in c...
#                                 ...
# 227418    never really gave it much thought i just figur...
# 227419                        nadie se salva de la regla xd
# 227420                     question are you a boy or a girl
# 227421    leave your email or phone number and maybe you...
# 227422    from the scenarios you present i see you belie...
# Name: text, Length: 227423, dtype: object

# %%
text_0 = ''.join(df[df['target']==0]['text'])

# %%
text_1 = ''.join(df[df['target']==1]['text'])

# %%
def remove_short_words(text, n=2):
    return ' '.join([word for word in text.split() if len(word)>n])

# %%
text_0 = remove_short_words(text_0)
text_1 = remove_short_words(text_1)

# %%
text_1[:1000]
# Out:
# 'after the wasted bit his sexuality haven read the above diatribe but one thing for absolute certain never the history this planet has umberto ever been referred humbert this kind lunacy that renders wikipedia fringe place for idiots play get serious dwerik for crying out loud you legally can have sex with children but not with underage children underage children are children beneath the legal age consent different states have the underage limit children most countries means someone under the age ireland for example child aged over the age consent britain you know the first thing about the topic the name standard english asage scandal pov term allegation allows the discussion cases that have not yet come court which cannot for technical reasons prosecuted and cases that were thrown invalid roman catholic church sex abuses allegations standard english means allegations about the roman catholic church public relations minor tabloid point when you are discussing the rape children stop addi'

# %%
wordcloud_1 = WordCloud(max_words=100).generate(text_1)
plt.figure(figsize=(12,6))
plt.imshow(wordcloud_1)
plt.axis("off")
plt.show()

# %%
wordcloud_1.words_
# Out:
# {'fuck': 1.0,
#  'people': 0.859624145785877,
#  'one': 0.7699316628701595,
#  'will': 0.7517084282460137,
#  'article': 0.729498861047836,
#  'know': 0.6449316628701595,
#  'think': 0.6136104783599089,
#  'page': 0.568621867881549,
#  'don': 0.5546697038724373,
#  'now': 0.5065489749430524,
#  'wikipedia': 0.48291571753986334,
#  'say': 0.46497722095671984,
#  'make': 0.44390660592255127,
#  'see': 0.4421981776765376,
#  'fucking': 0.4419134396355353,
#  'edit': 0.4174259681093394,
#  'stupid': 0.3972095671981777,
#  'time': 0.3906605922551253,
#  'want': 0.36332574031890663,
#  'really': 0.36161731207289294,
#  'way': 0.35734624145785876,
#  'look': 0.34851936218678814,
#  'thing': 0.34197038724373574,
#  'even': 0.3260250569476082,
#  'need': 0.3183371298405467,
#  'life': 0.3152050113895216,
#  'right': 0.30751708428246016,
#  'guy': 0.30580865603644647,
#  'going': 0.29954441913439633,
#  'back': 0.2955580865603645,
#  'fact': 0.2918564920273349,
#  'talk page': 0.2781890660592255,
#  'good': 0.2693621867881549,
#  'take': 0.2679384965831435,
#  'idiot': 0.265375854214123,
#  'moron moron': 0.26509111617312076,
#  'stop': 0.26480637813211844,
#  'block': 0.2613895216400911,
#  'little': 0.26110478359908884,
#  'well': 0.2554100227790433,
#  'nothing': 0.2537015945330296,
#  'made': 0.25341685649202733,
#  'someone': 0.2511389521640091,
#  'keep': 0.25028473804100226,
#  'still': 0.24544419134396356,
#  'man': 0.24174259681093394,
#  'comment': 0.23804100227790434,
#  'got': 0.2371867881548975,
#  'hell': 0.23633257403189067,
#  'never': 0.23433940774487472,
#  'come': 0.23348519362186787,
#  'use': 0.23120728929384965,
#  'much': 0.22978359908883828,
#  'mean': 0.2280751708428246,
#  'sexist': 0.22636674259681094,
#  'something': 0.22095671981776766,
#  'said': 0.21298405466970388,
#  'please': 0.21212984054669703,
#  'name': 0.21042141230068337,
#  'person': 0.208997722095672,
#  'women': 0.20842824601366744,
#  'tell': 0.20814350797266515,
#  'put': 0.20501138952164008,
#  'read': 0.20387243735763097,
#  'user': 0.20301822323462415,
#  'blocked': 0.19760820045558086,
#  'let': 0.19533029612756264,
#  'word': 0.19362186788154898,
#  'fack': 0.19248291571753987,
#  'dont': 0.19162870159453302,
#  'girl': 0.19134396355353075,
#  'anything': 0.1904897494305239,
#  'suck suck': 0.19020501138952164,
#  'world': 0.18878132118451024,
#  'bastered': 0.18735763097949887,
#  'editor': 0.18621867881548976,
#  'vandalism rules': 0.18194760820045558,
#  'rules vandalism': 0.18166287015945332,
#  'real': 0.18109339407744876,
#  'muslim': 0.17995444191343962,
#  'anyone': 0.17853075170842825,
#  'fuck yourselfgo': 0.1776765375854214,
#  'yourselfgo fuck': 0.17710706150341685,
#  'actually': 0.17596810933940774,
#  'reason': 0.17482915717539863,
#  'day': 0.1739749430523918,
#  'wrong': 0.17340546697038725,
#  'new': 0.1725512528473804,
#  'better': 0.1725512528473804,
#  'hope': 0.1714123006833713,
#  'first': 0.16970387243735763,
#  'thank': 0.16970387243735763,
#  'delete': 0.16913439635535307,
#  'site': 0.16856492027334852,
#  'call': 0.16856492027334852,
#  'seem': 0.16799544419134396,
#  'sucks cock': 0.1674259681093394,
#  'problem': 0.16714123006833714,
#  'asshole': 0.16429384965831434,
#  'talk': 0.16400911161731208}

# %%
wordcloud_0 = WordCloud(max_words=100).generate(text_0)
plt.figure(figsize=(12,6))
plt.imshow(wordcloud_0)
plt.axis("off")
plt.show()

# %%
wordcloud_0.words_
# Out:
# {'article': 1.0,
#  'one': 0.5062511324515311,
#  'think': 0.38112782106259185,
#  'talk page': 0.3327494916550905,
#  'see': 0.3151134464778241,
#  'page': 0.3134223188580862,
#  'people': 0.3005576694650802,
#  'edit': 0.28412957258762656,
#  'now': 0.28189486823297294,
#  'will': 0.2784924805218337,
#  'say': 0.27472770832075055,
#  'time': 0.25976928187473575,
#  'know': 0.24938092649634597,
#  'source': 0.23230859052565883,
#  'way': 0.2195043385476435,
#  'thank': 0.21869903968110166,
#  'name': 0.21435042580177568,
#  'fact': 0.21306194761530872,
#  'make': 0.20333796380181596,
#  'section': 0.2025729298786012,
#  'even': 0.19896921745082644,
#  'need': 0.19246642910350104,
#  'look': 0.18755410601759578,
#  'made': 0.18648708501942785,
#  'seem': 0.18548046143625052,
#  'editor': 0.18252098810170925,
#  'work': 0.1793199251072054,
#  'thing': 0.178494493769,
#  'link': 0.178273036580701,
#  'used': 0.17571621267943066,
#  'well': 0.17474985403958043,
#  'information': 0.17384389281472087,
#  'comment': 0.17249501721326327,
#  'may': 0.16852892029554467,
#  'use': 0.16808600591894668,
#  'said': 0.1654889170743492,
#  'reference': 0.16256970868313503,
#  'wikipedia': 0.1581405649171549,
#  'first': 0.15777818042721106,
#  'many': 0.15751645829558494,
#  'much': 0.15705341144732338,
#  'mean': 0.1526041352096797,
#  'read': 0.15161764409816594,
#  'case': 0.1515572466831753,
#  'word': 0.15101366994825954,
#  'someone': 0.14787300436874634,
#  'problem': 0.14624227416399913,
#  'list': 0.14569869742908337,
#  'something': 0.14503432586418635,
#  'point': 0.1450141933925228,
#  'user': 0.1447524712608967,
#  'change': 0.14424915946930805,
#  'issue': 0.14203458758631798,
#  'right': 0.13998107547663627,
#  'still': 0.13770610617865556,
#  'part': 0.13748464899035653,
#  'discussion': 0.13599484608725412,
#  'reason': 0.13414265869420788,
#  'new': 0.12999536953151739,
#  'question': 0.12715669102695737,
#  'believe': 0.12675404159368645,
#  'added': 0.12548569587888306,
#  'done': 0.12540516599222887,
#  'put': 0.1252441062189205,
#  'really': 0.12387509814579936,
#  'image': 0.12351271365585553,
#  'show': 0.12244569265768758,
#  'claim': 0.12129814177286545,
#  'back': 0.11958688168146403,
#  'actually': 0.11703005778019368,
#  'going': 0.11497654567051196,
#  'good': 0.11459402870890459,
#  'find': 0.1142920416339514,
#  'don': 0.11372833242737211,
#  'book': 0.11274184131585835,
#  'sure': 0.1121982645809426,
#  'two': 0.1119365424493165,
#  'history': 0.11113124358277465,
#  'removed': 0.11050713696120473,
#  'subject': 0.10980250045298061,
#  'rather': 0.1090575990014294,
#  'example': 0.10672223228845805,
#  'state': 0.10581627106359848,
#  'speedy deletion': 0.10509150208371082,
#  'come': 0.10450766040546798,
#  'thought': 0.10404461355720641,
#  'hope': 0.10344063940730003,
#  'opinion': 0.10293732761571138,
#  'give': 0.10249441323911336,
#  'block': 0.10112540516599224,
#  'anything': 0.10015904652614202,
#  'term': 0.10011878158281493,
#  'person': 0.09977652956453464,
#  'agree': 0.09935374765960017,
#  'found': 0.09915242294296471,
#  'want': 0.09903162811298342,
#  'place': 0.09804513700146968,
#  'best': 0.09715930824827364,
#  'content': 0.09643453926838598,
#  'got': 0.09544804815687222}
